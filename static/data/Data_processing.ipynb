# %%
import pandas as pd
import datetime

# %%
path = "../Major_Crime_Indicators_Open_Data.csv"

data_df = pd.read_csv(path)
data_df.head()
# Out:
#            X          Y  OBJECTID EVENT_UNIQUE_ID             REPORT_DATE
# 0 -79.425896  43.757346         1  GO-20141262074  2014/01/01 05:00:00+00  \
# 1 -79.350229  43.646293         2  GO-20141260701  2014/01/01 05:00:00+00
# 2 -79.376497  43.666423         3  GO-20141260889  2014/01/01 05:00:00+00
# 3 -85.488744   0.000000         4  GO-20141260973  2014/01/01 05:00:00+00
# 4 -79.344839  43.678946         5  GO-20141261050  2014/01/01 05:00:00+00
#
#                  OCC_DATE  REPORT_YEAR REPORT_MONTH  REPORT_DAY  REPORT_DOY
# 0  1998/06/01 04:00:00+00         2014      January           1           1  \
# 1  2014/01/01 05:00:00+00         2014      January           1           1
# 2  2014/01/01 05:00:00+00         2014      January           1           1
# 3  2014/01/01 05:00:00+00         2014      January           1           1
# 4  2014/01/01 05:00:00+00         2014      January           1           1
#
# ...

# %%
filter_df = data_df[data_df['OCC_YEAR']>2020]

# %%
filter_df['REPORT_DATE'] = pd.to_datetime(filter_df['REPORT_DATE'])
# Out:
# /var/folders/qh/th17k7b126bdp6fpt44nzdb80000gn/T/ipykernel_21117/2795198691.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter_df['REPORT_DATE'] = pd.to_datetime(filter_df['REPORT_DATE'])

# %%
filter_df['REPORT_DATE'] = filter_df['REPORT_DATE'].apply(lambda dt: dt.date())
# Out:
# /var/folders/qh/th17k7b126bdp6fpt44nzdb80000gn/T/ipykernel_21117/4288042646.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter_df['REPORT_DATE'] = filter_df['REPORT_DATE'].apply(lambda dt: dt.date())

# %%
filter_df.head()
# Out:
#                 X          Y  OBJECTID EVENT_UNIQUE_ID REPORT_DATE
# 246679 -79.382398  43.650271    246680     GO-20211618  2021-01-01  \
# 246681 -79.352620  43.665480    246682       GO-202155  2021-01-01
# 246682 -79.453947  43.750005    246683      GO-2021985  2021-01-01
# 246683 -79.223228  43.740459    246684      GO-2021945  2021-01-01
# 246684 -79.542161  43.748096    246685     GO-20215486  2021-01-01
#
#                       OCC_DATE  REPORT_YEAR REPORT_MONTH  REPORT_DAY
# 246679  2021/01/01 05:00:00+00         2021      January           1  \
# 246681  2021/01/01 05:00:00+00         2021      January           1
# 246682  2021/01/01 05:00:00+00         2021      January           1
# 246683  2021/01/01 05:00:00+00         2021      January           1
# 246684  2021/01/01 05:00:00+00         2021      January           1
#
#         REPORT_DOY  ... UCR_CODE  UCR_EXT                        OFFENCE
# ...

# %%
filter_df['OCC_DATE'] = pd.to_datetime(filter_df['OCC_DATE'])
filter_df['OCC_DATE'] = filter_df['OCC_DATE'].apply(lambda dt: dt.date())
# Out:
# /var/folders/qh/th17k7b126bdp6fpt44nzdb80000gn/T/ipykernel_21117/2079294688.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter_df['OCC_DATE'] = pd.to_datetime(filter_df['OCC_DATE'])
# /var/folders/qh/th17k7b126bdp6fpt44nzdb80000gn/T/ipykernel_21117/2079294688.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter_df['OCC_DATE'] = filter_df['OCC_DATE'].apply(lambda dt: dt.date())

# %%
filter_df.head()
# Out:
#                 X          Y  OBJECTID EVENT_UNIQUE_ID REPORT_DATE
# 246679 -79.382398  43.650271    246680     GO-20211618  2021-01-01  \
# 246681 -79.352620  43.665480    246682       GO-202155  2021-01-01
# 246682 -79.453947  43.750005    246683      GO-2021985  2021-01-01
# 246683 -79.223228  43.740459    246684      GO-2021945  2021-01-01
# 246684 -79.542161  43.748096    246685     GO-20215486  2021-01-01
#
#           OCC_DATE  REPORT_YEAR REPORT_MONTH  REPORT_DAY  REPORT_DOY  ...
# 246679  2021-01-01         2021      January           1           1  ...  \
# 246681  2021-01-01         2021      January           1           1  ...
# 246682  2021-01-01         2021      January           1           1  ...
# 246683  2021-01-01         2021      January           1           1  ...
# 246684  2021-01-01         2021      January           1           1  ...
#
#        UCR_CODE  UCR_EXT                        OFFENCE     MCI_CATEGORY
# ...

# %%
final_df = filter_df[['X', 'Y', 'OBJECTID', 'EVENT_UNIQUE_ID', 'REPORT_DATE', 'OCC_DATE',
        'OCC_YEAR', 'OCC_MONTH','OCC_HOUR', 'DIVISION', 'LOCATION_TYPE', 'PREMISES_TYPE', 'OFFENCE', 'MCI_CATEGORY', 'HOOD_158', 'NEIGHBOURHOOD_158',
       'HOOD_140', 'NEIGHBOURHOOD_140']]

# %%
def convert_to_date(date_str):
    return pd.to_datetime(date_str, format='%m/%d/%Y')  # Adjust the format as needed

# Apply the function to the 'REPORT_DATE' and 'OCC_DATE' columns
final_df['REPORT_DATE'] = final_df['REPORT_DATE'].apply(convert_to_date)
final_df['OCC_DATE'] = final_df['OCC_DATE'].apply(convert_to_date)
# Out:
# /var/folders/qh/th17k7b126bdp6fpt44nzdb80000gn/T/ipykernel_21117/222416067.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['REPORT_DATE'] = final_df['REPORT_DATE'].apply(convert_to_date)
# /var/folders/qh/th17k7b126bdp6fpt44nzdb80000gn/T/ipykernel_21117/222416067.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['OCC_DATE'] = final_df['OCC_DATE'].apply(convert_to_date)

# %%
final_df = final_df[final_df['Y']!=0]

# %%
final_df = final_df[final_df['HOOD_140']!='NSA']

# %%
final_df.head()
# Out:
#                 X          Y  OBJECTID EVENT_UNIQUE_ID REPORT_DATE   OCC_DATE
# 246679 -79.382398  43.650271    246680     GO-20211618  2021-01-01 2021-01-01  \
# 246681 -79.352620  43.665480    246682       GO-202155  2021-01-01 2021-01-01
# 246682 -79.453947  43.750005    246683      GO-2021985  2021-01-01 2021-01-01
# 246683 -79.223228  43.740459    246684      GO-2021945  2021-01-01 2021-01-01
# 246684 -79.542161  43.748096    246685     GO-20215486  2021-01-01 2021-01-01
#
#         OCC_YEAR OCC_MONTH  OCC_HOUR DIVISION
# 246679    2021.0   January         7      D52  \
# 246681    2021.0   January         0      D55
# 246682    2021.0   January         3      D32
# 246683    2021.0   January         3      D43
# 246684    2021.0   January        23      D31
#
#                                             LOCATION_TYPE PREMISES_TYPE
# 246679                   Apartment (Rooming House, Condo)     Apartment  \
# ...

# %%
final_df.reset_index()
# Out:
#         index          X          Y  OBJECTID EVENT_UNIQUE_ID REPORT_DATE
# 0      246679 -79.382398  43.650271    246680     GO-20211618  2021-01-01  \
# 1      246681 -79.352620  43.665480    246682       GO-202155  2021-01-01
# 2      246682 -79.453947  43.750005    246683      GO-2021985  2021-01-01
# 3      246683 -79.223228  43.740459    246684      GO-2021945  2021-01-01
# 4      246684 -79.542161  43.748096    246685     GO-20215486  2021-01-01
# ...       ...        ...        ...       ...             ...         ...
# 73489  323291 -79.301740  43.736102    323292  GO-20222554300  2022-12-31
# 73490  323292 -79.258639  43.828794    323293  GO-20222557893  2022-12-31
# 73491  323293 -79.425645  43.701404    323294  GO-20222559486  2022-12-31
# 73492  323294 -79.385170  43.672134    323295  GO-20222557956  2022-12-31
# 73493  323295 -79.248081  43.736690    323296  GO-20222558010  2022-12-31
#
#         OCC_DATE  OCC_YEAR OCC_MONTH  OCC_HOUR DIVISION
# ...

# %%
final_df['OBJECTID'] = final_df.index

# %%
#final_df_2018 = final_df.loc[final_df['OCC_YEAR']==2018,:]
#final_df_2019 = final_df.loc[final_df['OCC_YEAR']==2019,:]
#final_df_2020 = final_df.loc[final_df['OCC_YEAR']==2020,:]
#final_df_2021 = final_df.loc[final_df['OCC_YEAR']==2021,:]
#final_df_2022 = final_df.loc[final_df['OCC_YEAR']==2022,:]

# %%
#final_df_2018

# %%
final_df.to_csv('Modified_major_crime.csv')

# %%
#final_df_2018.to_csv('major_crime_2018.csv')
#final_df_2019.to_csv('major_crime_2019.csv')
#final_df_2020.to_csv('major_crime_2020.csv')
#final_df_2021.to_csv('major_crime_2021.csv')
#final_df_2022.to_csv('major_crime_2022.csv')

# %%
#final_df_2018.to_json("major_crime_2018.json",orient='records',lines=True)
#final_df_2019.to_json("major_crime_2019.json",orient='records',lines=True)
#final_df_2020.to_json("major_crime_2020.json",orient='records',lines=True)
#final_df_2021.to_json("major_crime_2021.json",orient='records',lines=True)
#final_df_2022.to_json("major_crime_2022.json",orient='records',lines=True)

# %%
import csv
import json
input_file = 'Modified_major_crime.csv'
output_file = 'Modified_major_crime.json'

csv_records = []
with open(input_file, 'r') as csv_file:
    csv_reader = csv.DictReader(csv_file)
    for row in csv_reader:
        csv_records.append(row)

# Write JSON with commas between records
with open(output_file, 'w') as json_file:
    json_file.write('[')
    for index, record in enumerate(csv_records):
        json.dump(record, json_file, indent=2)
        if index < len(csv_records) - 1:
            json_file.write(',')
    json_file.write(']')
